# %%
f = open('logs/LinearFANetwork_5.txt')
L = f.readlines()
f.close()

# %%
losses = []
iters = []
for l in L:
    l = l.replace('\n', '')
    l = l.split(' ')
    loss = float(l[5])
    losses.append(loss)

# %%
import matplotlib.pyplot as plt

plt.scatter(list(range(len(losses))), losses, s=1)
